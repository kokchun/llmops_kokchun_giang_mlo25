# %%
from pathlib import Path 

text = "hej på dig"

Path("output_files").mkdir(exist_ok=True)

output_folder = Path("output_files")

with open(output_folder / "test1.txt", "w") as file:
    file.write(text)
